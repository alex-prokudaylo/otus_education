# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for plotting the data 
import seaborn as sns # Advanced data plotting on top of matplotlib
import os


from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

import cv2
from PIL import Image

# %%
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))
#/kaggle/input/h-and-m-personalized-fashion-recommendations/sample_submission.csv
#/kaggle/input/h-and-m-personalized-fashion-recommendations/articles.csv
#/kaggle/input/h-and-m-personalized-fashion-recommendations/transactions_train.csv
#/kaggle/input/h-and-m-personalized-fashion-recommendations/customers.csv

# %% [markdown]
# **About data**
#
# *images* - a folder of images corresponding to each article_id; images are placed in subfolders starting with the first three digits of the article_id; note, not all article_id values have a corresponding image.
#
# *articles.csv* - detailed metadata for each article_id available for purchase
#
# *customers.csv* - metadata for each customer_id in dataset
#
# *sample_submission.csv* - a sample submission file in the correct format
#
# *transactions_train.csv* - the training data, consisting of the purchases each customer for each date, as well as additional information. Duplicate rows correspond to multiple purchases of the same item. Your task is to predict the article_ids each customer will purchase during the 7-day period immediately after the training data period.
#
# *target*: Make predictions for all customer_id values found in the sample submission. All customers who made purchases during the test period are scored, regardless of whether they had purchase history in the training data.
#
# Submissions are evaluated according to the Mean Average Precision @ 12 (MAP@12).
# For each customer_id observed in the training data, you may predict up to 12 labels for the article_id, which is the predicted items a customer will buy in the next 7-day period after the training time period.

# %% [markdown]
# # EDA

# %% [markdown]
# **Transactions data**

# %%
transactions_df = pd.read_csv("/kaggle/input/h-and-m-personalized-fashion-recommendations/transactions_train.csv")#, nrow=10000)
print(transactions_df.shape)
transactions_df.head()
# Out:
# (31788324, 5)
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
#
#       price  sales_channel_id
# 0  0.050831                 2
# 1  0.030492                 2
# 2  0.015237                 2
# 3  0.016932                 2
# 4  0.016932                 2

# %%
# Number of unique meanings  of customers and articles
print(len(transactions_df.customer_id.unique()))
print(len(transactions_df.article_id.unique()))
# Out:
# 1362281
# 104547

# %%
# let's takr peace of data
transactions_df_sample = transactions_df.iloc[:200000,:].copy()
transactions_df_sample.shape
# Out:
# (200000, 5)

# %%
# Number of unique meanings  of customers and articles
print(len(transactions_df_sample.customer_id.unique()))
print(len(transactions_df_sample.article_id.unique()))
# Out:
# 51527
# 19519

# %%
print(transactions_df_sample.groupby("customer_id")["article_id"].count().mean())
transactions_df_sample.groupby("customer_id")["article_id"].count().value_counts()
# Out:
# 3.881460205329245
# 1      13984
# 2      11085
# 3       7350
# 4       5118
# 5       3313
# 6       2589
# 7       1775
# 8       1452
# 9       1050
# 10       787
# 11       602
# 12       445
# 13       365
# 14       283
# 15       237
# 16       179
# 17       144
# 19       117
# 18       114
# 20        94
# 21        60
# 24        55
# 22        48
# 23        42
# 25        34
# 26        34
# 28        27
# 27        20
# 31        17
# 29        16
# 32        13
# 30        11
# 33        10
# 37         8
# 36         7
# 34         7
# 39         5
# 35         4
# 40         4
# 52         3
# 38         2
# 48         2
# 42         2
# 46         1
# 103        1
# 55         1
# 80         1
# 43         1
# 51         1
# 44         1
# 54         1
# 45         1
# 41         1
# 100        1
# 47         1
# 72         1
# Name: article_id, dtype: int64

# %%
print(transactions_df_sample.groupby("article_id")["customer_id"].count().value_counts().mean())
transactions_df_sample.groupby("article_id")["customer_id"].count().value_counts()
# Out:
# 92.07075471698113
# 1      5114
# 2      2743
# 3      1901
# 4      1372
# 5      1069
#        ...
# 163       1
# 143       1
# 392       1
# 189       1
# 169       1
# Name: customer_id, Length: 212, dtype: int64

# %% [markdown]
# **Exclude hiden transactions**

# %%
customer_test_df = pd.read_csv("../input/fork-of-h-m-recsys-eda-and-split/customer_test.csv")
customer_test_df.head()

customer_test_df_open_transactions = pd.read_csv("../input/fork-of-h-m-recsys-eda-and-split/customer_test_df_open_transactions.csv", index_col=0)
customer_test_df_hiden_transactions = pd.read_csv("../input/fork-of-h-m-recsys-eda-and-split/customer_test_df_hiden_transactions.csv", index_col=0)

customer_test_df_hiden_transactions.head()
# Out:
#                                          customer_id       t_dat  article_id  \
# 0  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...  2018-09-20   640639001
# 1  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...  2018-09-20   640639001
# 2  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...  2018-09-20   664421002
# 3  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...  2018-09-20   664421002
# 4  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...  2018-09-20   680912009
#
#       price  sales_channel_id
# 0  0.010153                 2
# 1  0.010153                 2
# 2  0.016932                 2
# 3  0.016932                 2
# 4  0.011847                 2

# %%
customer_test_df
# Out:
#                                            customer_id  article_id
# 0    000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...          30
# 1    001521e8394eb81ba43ab5b84ae7e756d51ac813be212a...          34
# 2    00294f5274dbc84408d60fc661860d385c2901dccca8c4...          48
# 3    002975c14a1aecac230ebf40c314fcad04ee3140e9bef2...          32
# 4    002e0bc901590e07341001b2358bded94031771537c24b...          21
# ..                                                 ...         ...
# 495  66d2a38564a9e06648fc37a0ec21bde01ac83e5e097c53...          24
# 496  66e6f5381c89f34bd153c33b6620255ff3edb187e43921...          16
# 497  66fa67a372ff71bba24308b3650549eb895791545b50a3...          16
# 498  67a84660743ba09cc4784425465efd354b153cd1fb0d34...          17
# 499  67c3ffa39a4fadb2bc4ff6b691b3fa26d7915131949b82...          27
#
# [500 rows x 2 columns]

# %%
print(transactions_df_sample.shape)
for customer in customer_test_df.customer_id.values:
    transactions_df_sample.drop(transactions_df_sample[transactions_df_sample.customer_id == customer].index, inplace=True)
print(transactions_df_sample.shape)
# Out:
# (200000, 5)
# (188883, 5)

# %%
transactions_df_sample = pd.concat([transactions_df_sample, customer_test_df_open_transactions])
print(transactions_df_sample.shape)
# Out:
# (194000, 5)

# %% [markdown]
# **Articles data**

# %%
articles_df = pd.read_csv("/kaggle/input/h-and-m-personalized-fashion-recommendations/articles.csv")
print(articles_df.shape)
articles_df.head().T
# Out:
# (105542, 25)
#                                                                     0  \
# article_id                                                  108775015
# product_code                                                   108775
# prod_name                                                   Strap top
# product_type_no                                                   253
# product_type_name                                            Vest top
# product_group_name                                 Garment Upper body
# graphical_appearance_no                                       1010016
# graphical_appearance_name                                       Solid
# colour_group_code                                                   9
# colour_group_name                                               Black
# perceived_colour_value_id                                           4
# perceived_colour_value_name                                      Dark
# perceived_colour_master_id                                          5
# perceived_colour_master_name                                    Black
# department_no                                                    1676
# department_name                                          Jersey Basic
# index_code                                                          A
# index_name                                                 Ladieswear
# index_group_no                                                      1
# index_group_name                                           Ladieswear
# section_no                                                         16
# section_name                                   Womens Everyday Basics
# garment_group_no                                                 1002
# garment_group_name                                       Jersey Basic
# detail_desc                   Jersey top with narrow shoulder straps.
#
#                                                                     1  \
# article_id                                                  108775044
# product_code                                                   108775
# prod_name                                                   Strap top
# product_type_no                                                   253
# product_type_name                                            Vest top
# product_group_name                                 Garment Upper body
# graphical_appearance_no                                       1010016
# graphical_appearance_name                                       Solid
# colour_group_code                                                  10
# colour_group_name                                               White
# perceived_colour_value_id                                           3
# perceived_colour_value_name                                     Light
# perceived_colour_master_id                                          9
# perceived_colour_master_name                                    White
# department_no                                                    1676
# department_name                                          Jersey Basic
# index_code                                                          A
# index_name                                                 Ladieswear
# index_group_no                                                      1
# index_group_name                                           Ladieswear
# section_no                                                         16
# section_name                                   Womens Everyday Basics
# garment_group_no                                                 1002
# garment_group_name                                       Jersey Basic
# detail_desc                   Jersey top with narrow shoulder straps.
#
#                                                                     2  \
# article_id                                                  108775051
# product_code                                                   108775
# prod_name                                               Strap top (1)
# product_type_no                                                   253
# product_type_name                                            Vest top
# product_group_name                                 Garment Upper body
# graphical_appearance_no                                       1010017
# graphical_appearance_name                                      Stripe
# colour_group_code                                                  11
# colour_group_name                                           Off White
# perceived_colour_value_id                                           1
# perceived_colour_value_name                               Dusty Light
# perceived_colour_master_id                                          9
# perceived_colour_master_name                                    White
# department_no                                                    1676
# department_name                                          Jersey Basic
# index_code                                                          A
# index_name                                                 Ladieswear
# index_group_no                                                      1
# index_group_name                                           Ladieswear
# section_no                                                         16
# section_name                                   Womens Everyday Basics
# garment_group_no                                                 1002
# garment_group_name                                       Jersey Basic
# detail_desc                   Jersey top with narrow shoulder straps.
#
#                                                                               3  \
# article_id                                                            110065001
# product_code                                                             110065
# prod_name                                                     OP T-shirt (Idro)
# product_type_no                                                             306
# product_type_name                                                           Bra
# product_group_name                                                    Underwear
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                             9
# colour_group_name                                                         Black
# perceived_colour_value_id                                                     4
# perceived_colour_value_name                                                Dark
# perceived_colour_master_id                                                    5
# perceived_colour_master_name                                              Black
# department_no                                                              1339
# department_name                                                  Clean Lingerie
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   61
# section_name                                                    Womens Lingerie
# garment_group_no                                                           1017
# garment_group_name                                            Under-, Nightwear
# detail_desc                   Microfibre T-shirt bra with underwired, moulde...
#
#                                                                               4
# article_id                                                            110065002
# product_code                                                             110065
# prod_name                                                     OP T-shirt (Idro)
# product_type_no                                                             306
# product_type_name                                                           Bra
# product_group_name                                                    Underwear
# graphical_appearance_no                                                 1010016
# graphical_appearance_name                                                 Solid
# colour_group_code                                                            10
# colour_group_name                                                         White
# perceived_colour_value_id                                                     3
# perceived_colour_value_name                                               Light
# perceived_colour_master_id                                                    9
# perceived_colour_master_name                                              White
# department_no                                                              1339
# department_name                                                  Clean Lingerie
# index_code                                                                    B
# index_name                                                     Lingeries/Tights
# index_group_no                                                                1
# index_group_name                                                     Ladieswear
# section_no                                                                   61
# section_name                                                    Womens Lingerie
# garment_group_no                                                           1017
# garment_group_name                                            Under-, Nightwear
# detail_desc                   Microfibre T-shirt bra with underwired, moulde...

# %%
# Number of unique meanings of article features
for col in articles_df.columns:
    print(col, len(articles_df[col].unique()))
# Out:
# article_id 105542
# product_code 47224
# prod_name 45875
# product_type_no 132
# product_type_name 131
# product_group_name 19
# graphical_appearance_no 30
# graphical_appearance_name 30
# colour_group_code 50
# colour_group_name 50
# perceived_colour_value_id 8
# perceived_colour_value_name 8
# perceived_colour_master_id 20
# perceived_colour_master_name 20
# department_no 299
# department_name 250
# index_code 10
# index_name 10
# index_group_no 5
# index_group_name 5
# section_no 57
# section_name 56
# garment_group_no 21
# garment_group_name 21
# detail_desc 43405

# %% [markdown]
# **Feature Engeneering**

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()
transactions_df_sample[['article_id_enc', 'customer_id_enc']] = enc.fit_transform(transactions_df_sample[['article_id', 'customer_id']]) 

transactions_df_sample.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
#
#       price  sales_channel_id  article_id_enc  customer_id_enc
# 0  0.050831                 2         16536.0              1.0
# 1  0.030492                 2          3753.0              1.0
# 2  0.015237                 2          2446.0              2.0
# 3  0.016932                 2         18442.0              2.0
# 4  0.016932                 2         18443.0              2.0

# %%
transactions_df_sample['article_id_enc'] = transactions_df_sample['article_id_enc'].astype(int)
transactions_df_sample['customer_id_enc'] = transactions_df_sample['customer_id_enc'].astype(int)

# %%
item_features = articles_df[['product_type_no', 'index_group_no', 'garment_group_no', 'article_id']].copy()
item_features = item_features.merge(transactions_df_sample[['article_id_enc','article_id']].drop_duplicates(), how="left", on="article_id")
item_features.dropna(axis=0, inplace=True)
item_features['article_id_enc'] = item_features['article_id_enc'].astype(int)
item_features.set_index("article_id_enc", inplace=True)
item_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19294 entries, 0 to 19293
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_type_no   19294 non-null  int64
#  1   index_group_no    19294 non-null  int64
#  2   garment_group_no  19294 non-null  int64
#  3   article_id        19294 non-null  int64
# dtypes: int64(4)
# memory usage: 753.7 KB

# %%
#train_df, test_df = train_test_split(transactions_df_sample, test_size=0.1, random_state=42)

# %% [markdown]
# # Collaborative filtering

# %%
import scipy.sparse as sp
from lightfm import LightFM
from lightfm.evaluation import precision_at_k
from lightfm.evaluation import auc_score

from lightfm.cross_validation import random_train_test_split
from lightfm.data import Dataset

# %%
# Convert data to sparse matrix
# (np.float32 coo_matrix of shape [n_users, n_items]) – the matrix containing user-item interactions. 
# Will be converted to numpy.float32 dtype if it is not of that type.

data_sp = sp.coo_matrix((np.ones(transactions_df_sample.shape[0]), (transactions_df_sample.customer_id_enc.values, transactions_df_sample.article_id_enc.values ) ))
data_sp.shape
# Out:
# (51527, 19294)

# %%
# build item features
# item_features (np.float32 csr_matrix of shape [n_items, n_item_features], optional) – Each row contains that item’s weights over features.
item_features_product_type_no = pd.get_dummies(item_features["index_group_no"])
item_features_product_type_no.shape

item_features_csr = sp.csr_matrix(item_features_product_type_no.values)
item_features_csr.shape
# Out:
# (19294, 5)

# %%
# Make split
#train_sp, valid_sp = random_train_test_split(data_sp, test_percentage=0.2, random_state=42)

# %%
# Define the model

model = LightFM(no_components=30, loss='warp', random_state=42)
model.fit(data_sp, epochs=10, num_threads=2)

# %%
# Evaluate the model
#print("Train AUC: %.2f" % auc_score(model, train_sp).mean())
#print("Valid AUC: %.2f" % auc_score(model, valid_sp).mean())

# %%
#model.predict(train_df.customer_id_enc.values, train_df.article_id_enc.values)

# %%
# Model with item features
model2 = LightFM(no_components=40, loss='warp', random_state=42)
model2.fit(data_sp, item_features=item_features_csr, epochs=20, num_threads=2)

# %%
# Evaluate the model
#print("Train AUC: %.2f" % auc_score(model2, train_sp, item_features=item_features_csr).mean())
#print("Valid AUC: %.2f" % auc_score(model2, valid_sp, item_features=item_features_csr).mean())

# %%
# Dictinary for index converting
article_dict = dict(zip(transactions_df_sample["article_id_enc"].values, transactions_df_sample["article_id"].values))

items = transactions_df_sample.article_id_enc.unique()

# %%
def sample_recommendation(model, transactions_df, articles_df, article_dict, num, user_ids):

    
    #print(items[:10])
    recomends = []

    for user_id in user_ids:
        print()
        print("*" * 60)
        print("  Recomendations for user_id =", user_id)
        print("*" * 60)
        
        print("\n     Already bought:")
        rtg = transactions_df[transactions_df["customer_id_enc"] == user_id]["article_id"].values
        
        #print("{:10}  {:25} {:20} {:20} {:40}".format("id", "prod name", "product type name","index group name", "section name"))
        #print()

        for item in rtg:           
            print("{:10}  {:25} {:20} {:20} {:40}".format(item, articles_df.loc[item, "prod_name"], articles_df.loc[item, "product_type_name"],
                                                          articles_df.loc[item, "index_group_name"],
                                                          articles_df.loc[item, "section_name"]
                                                          ))

        # make prediction 
        scores = model.predict(np.ones(len(items)) * user_id, items)
        
        # n-top score 
        num_of_cand = 50
        argsort_scores_idx = np.argsort(scores)[-num_of_cand:]
        argsort_scores_idx = np.flip(argsort_scores_idx)

        
        
        print("\n     Recommended:")
        k = 1
        
        recs = []
        for ind in argsort_scores_idx:
            #print(i, items[i],article_dict[items[i]])
            ii = article_dict[items[ind]]
            
            # check if already bought
            if ii in rtg:
                continue
            else: k+=1
            
            recs.append(ii)
            
            print("{:10}  {:25} {:20} {:20} {:40} score={:.3}".format(ii, articles_df.loc[ii, "prod_name"], 
                                                          articles_df.loc[ii, "product_type_name"],
                                                          articles_df.loc[ii, "index_group_name"],
                                                          articles_df.loc[ii, "section_name"],
                                                          scores[ind]     
                                                          ))
            if k > num: break
        #print()
        
        recomends.append(recs)
        
    return recomends
        
#recomends = sample_recommendation(model, transactions_df_sample, articles_df.set_index("article_id"), article_dict, 5, [8, 23])

# %%
# use for test
sample_articles_id = 541518023
customer_test_df['article_id'] = sample_articles_id

customer_test_df[['article_id_enc', 'customer_id_enc']] = enc.transform(customer_test_df[['article_id', 'customer_id']])
customer_test_df[:10]

#
# Out:
#                                          customer_id  article_id  \
# 0  000aa7f0dc06cd7174389e76c9e132a67860c5f65f9706...   541518023
# 1  001521e8394eb81ba43ab5b84ae7e756d51ac813be212a...   541518023
# 2  00294f5274dbc84408d60fc661860d385c2901dccca8c4...   541518023
# 3  002975c14a1aecac230ebf40c314fcad04ee3140e9bef2...   541518023
# 4  002e0bc901590e07341001b2358bded94031771537c24b...   541518023
# 5  0063a5fab642a52b80dcc5561b3a2ef5a06f13f2967a7a...   541518023
# 6  00a5601e1e207751fefbfc0c00006454e20a571a2dbdd1...   541518023
# 7  0162c0eacae80811a6b926cb3432888bc3f5fffb963b66...   541518023
# 8  01a654dd9975ab239e1aacceb81dba8ca3a2208cfe3aef...   541518023
# 9  02717e619ad29222aad577e1f59561906db8c725cb911a...   541518023
#
#    article_id_enc  customer_id_enc
# 0          3753.0             12.0
# 1          3753.0             21.0
# 2          3753.0             38.0
# 3          3753.0             39.0
# 4          3753.0             44.0
# 5          3753.0             95.0
# 6          3753.0            161.0
# 7          3753.0            334.0
# 8          3753.0            391.0
# 9          3753.0            562.0

# %%
lightfm_preds = sample_recommendation(model, transactions_df_sample, articles_df.set_index("article_id"), article_dict, 12, customer_test_df.customer_id_enc.values)
# Out:
# ************************************************************
#   Recomendations for user_id = 12.0
# ************************************************************
#
#      Already bought:
#  501820043  SIRPA                     Sweater              Divided              Divided Collection
#  501820043  SIRPA                     Sweater              Divided              Divided Collection
#  674681001  Felicia Tank              Vest top             Divided              Divided Basics
#  671505001  EDC ROMAN BLOUSE          Blouse               Ladieswear           Womens Everyday Collection
#  671505001  EDC ROMAN BLOUSE          Blouse               Ladieswear           Womens Everyday Collection
#  631848002  RICHIE PELATED SKIRT      Skirt                Divided              Divided Collection
#  631848002  RICHIE PELATED SKIRT      Skirt                Divided              Divided Collection
#  631848002  RICHIE PELATED SKIRT      Skirt                Divided              Divided Collection
#  631848002  RICHIE PELATED SKIRT      Skirt                Divided              Divided Collection
#  680187001  HOPPER 9.99               Vest top             Divided              Divided Collection
#  676827002  Bientot graphic tee       T-shirt              Ladieswear           Womens Trend
#  676827002  Bientot graphic tee       T-shirt              Ladieswear           Womens Trend
#  685687002  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection
#  685687002  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection
#  680912006  Linni tee                 T-shirt              Divided              Divided Collection
#  680912006  Linni tee                 T-shirt              Divided              Divided Collection
#  692454002  EDC LAURA LACE TOP        Top                  Ladieswear           Womens Everyday Collection
#  692454002  EDC LAURA LACE TOP        Top                  Ladieswear           Womens Everyday Collection
#
#      Recommended:
#  685687001  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=2.52
#  685687004  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=2.48
#  687424003  Ocean                     Dress                Ladieswear           Womens Everyday Collection               score=2.42
#  693584002  Lotus                     Dress                Ladieswear           Womens Everyday Collection               score=2.41
#  687424002  Ocean                     Dress                Ladieswear           Womens Everyday Collection               score=2.29
#  662857005  Cindererlla               Sweater              Ladieswear           Womens Everyday Collection               score=2.28
#  685687003  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=2.18
#  662857004  Cindererlla               Sweater              Ladieswear           Womens Everyday Collection               score=2.16
#  637549003  Bama                      Sweater              Ladieswear           Womens Everyday Collection               score=2.13
#  660599003  Baraboom                  Cardigan             Ladieswear           Womens Everyday Collection               score=2.12
#  524825013  Latte slacks (1)          Trousers             Ladieswear           Womens Everyday Collection               score=2.1
#  665975002  Verity V-neck             Sweater              Divided              Divided Collection                       score=2.03
#
# ************************************************************
#   Recomendations for user_id = 21.0
# ************************************************************
#
#      Already bought:
#  705691001  Dee dee lace              Sweater              Baby/Children        Kids Girl
#  705691001  Dee dee lace              Sweater              Baby/Children        Kids Girl
#  287645003  Microtights 2pk SG        Underwear Tights     Baby/Children        Girls Underwear & Basics
#  293433027  Basic 2pk tights SG       Underwear Tights     Baby/Children        Girls Underwear & Basics
#  293433027  Basic 2pk tights SG       Underwear Tights     Baby/Children        Girls Underwear & Basics
#  661136002  Barbro Cord Dungaree      Dress                Baby/Children        Kids Girl
#  661136002  Barbro Cord Dungaree      Dress                Baby/Children        Kids Girl
#  653323002  Totte Set                 Top                  Baby/Children        Kids Girl
#  287645023  2-p micro tights SG       Underwear Tights     Baby/Children        Girls Underwear & Basics
#  293433026  2-p basic cotton tights SG Underwear Tights     Baby/Children        Girls Underwear & Basics
#  293433026  2-p basic cotton tights SG Underwear Tights     Baby/Children        Girls Underwear & Basics
#  659280002  Nova 2pack                Cardigan             Baby/Children        Kids Girl
#  659280002  Nova 2pack                Cardigan             Baby/Children        Kids Girl
#  293433018  2-p basic cotton tights SG Underwear Tights     Baby/Children        Girls Underwear & Basics
#  293433018  2-p basic cotton tights SG Underwear Tights     Baby/Children        Girls Underwear & Basics
#  659320001  Klara Dress               Dress                Baby/Children        Kids Girl
#  659320001  Klara Dress               Dress                Baby/Children        Kids Girl
#  575156003  FREJA 3-PACK              T-shirt              Baby/Children        Girls Underwear & Basics
#  575156003  FREJA 3-PACK              T-shirt              Baby/Children        Girls Underwear & Basics
#  660590001  Naomi                     Trousers             Baby/Children        Kids Girl
#  637352001  SHANE HOOD                Hoodie               Baby/Children        Kids Boy
#  637352001  SHANE HOOD                Hoodie               Baby/Children        Kids Boy
#
#      Recommended:
#  575523002  AXEL JOGGERS              Trousers             Baby/Children        Kids Boy                                 score=2.26
#  571436009  Tess Tee                  T-shirt              Divided              Divided Basics                           score=2.21
#  729931001  ED Coated leggings.       Trousers             Ladieswear           H&M+                                     score=2.18
#  626263006  GILDA LEGGINGS            Leggings/Tights      Baby/Children        Young Girl                               score=2.13
#  667999003  Ledger set                T-shirt              Baby/Children        Young Boy                                score=2.07
#  657165002  TUXEDO pant               Leggings/Tights      Baby/Children        Young Girl                               score=2.07
#  542982010  TP KEVIN sweatpants BB    Trousers             Baby/Children        Boys Underwear & Basics                  score=2.05
#  651793004  Craven set                Sweater              Baby/Children        Young Girl                               score=1.87
#  626440010  BRITTA / PRICE SWETTIS    Sweater              Baby/Children        Young Girl                               score=1.87
#  640001002  Low price                 Pyjama set           Baby/Children        Boys Underwear & Basics                  score=1.83
#  579837001  Denim skirt               Skirt                Ladieswear           H&M+                                     score=1.83
#  617322005  Glans tunic               Blouse               Ladieswear           H&M+                                     score=1.82
#
# ************************************************************
#   Recomendations for user_id = 38.0
# ************************************************************
#
#      Already bought:
#  553873002  Dragonfly                 Dress                Baby/Children        Kids Girl
#  651687001  Oprah                     Blouse               Ladieswear           Womens Everyday Collection
#  642105001  Bonnie flowy blouse       Blouse               Ladieswear           Womens Casual
#  446224024  Maja Cardigan             Cardigan             Divided              Divided Collection
#  640033003  Cleo Skirt.               Skirt                Baby/Children        Girls Underwear & Basics
#  583786001  Filippa singoalla top     Top                  Baby/Children        Kids Girl
#  464454004  TANJA SKIRT               Skirt                Divided              Divided Collection
#  623733004  LAILA playsuit            Garment Set          Baby/Children        Girls Underwear & Basics
#  629661001  Pimms tights              Leggings/Tights      Baby/Children        Kids Girl
#  566288002  Sunglasses Gwen           Sunglasses           Baby/Children        Kids Accessories, Swimwear & D
#  635418002  Leya                      Blouse               Ladieswear           Womens Everyday Collection
#  564231008  Shanta short              Shorts               Baby/Children        Kids Girl
#  570189002  June Jeggings             Leggings/Tights      Divided              Divided Collection
#  636236007  Holly Trousers            Trousers             Baby/Children        Kids Girl
#  520567001  Deal tulle                Skirt                Baby/Children        Kids Girl
#  575542003  Summer pants (Saigon)     Trousers             Ladieswear           Womens Everyday Collection
#  640033002  Cleo Skirt.               Skirt                Baby/Children        Girls Underwear & Basics
#  553875002  Palma tee                 T-shirt              Baby/Children        Kids Girl
#  553488001  Molko Treggings           Leggings/Tights      Baby/Children        Kids Girl
#  577529001  Taylor blouse             Blouse               Ladieswear           Womens Casual
#  573856024  Snap 5 pocket             Trousers             Ladieswear           Womens Casual
#  553488003  Molko Treggings           Leggings/Tights      Baby/Children        Kids Girl
#  510407031  MAXI                      Leggings/Tights      Baby/Children        Girls Underwear & Basics
#  640033001  Cleo Skirt.               Skirt                Baby/Children        Girls Underwear & Basics
#  584778002  Basic cropped leggings    Leggings/Tights      Ladieswear           H&M+
#  590547001  Harriet Cargo             Trousers             Baby/Children        Kids Girl
#  642105002  Bonnie flowy blouse       Blouse               Ladieswear           Womens Casual
#  640033005  Cleo Skirt.               Skirt                Baby/Children        Girls Underwear & Basics
#  565183003  Justin dress              Dress                Baby/Children        Kids Girl
#  500153006  Dance shoe Sofia          Other shoe           Baby/Children        Kids Accessories, Swimwear & D
#  643135001  LEGGINGS CAPRI            Trousers             Baby/Children        Kids Girl
#  540701004  Bella Biker Leggings      Leggings/Tights      Divided              Divided Collection
#  565202002  James leggings OL unique  Leggings/Tights      Baby/Children        Kids Girl
#  590207001  Maisy sailor dress        Dress                Baby/Children        Kids Girl
#  522398011  Vincent (1)               Top                  Ladieswear           Womens Everyday Collection
#  567594001  Cosy tunic                Dress                Ladieswear           H&M+
#
#      Recommended:
#  479227020  Stacy                     T-shirt              Ladieswear           Womens Everyday Basics                   score=2.19
#  616030001  Shoulder top              Top                  Ladieswear           Womens Everyday Collection               score=2.08
#  517462001  Anja jacquard dress       Top                  Ladieswear           Womens Casual                            score=2.0
#  397068014  Skinny L.W Bargain (1)    Trousers             Menswear             Denim Men                                score=1.79
#  651244001  ROSIE FRILL ONE SHOULDER  Top                  Ladieswear           Womens Casual                            score=1.68
#  312543001  Biker Leggings (1)        Leggings/Tights      Divided              Divided Selected                         score=1.66
#  626405004  Annabel V-neck LS         T-shirt              Ladieswear           Womens Casual                            score=1.6
#  581162008  Beth sandal               Sandals              Ladieswear           Womens Shoes                             score=1.57
#  681196003  Morissette                T-shirt              Ladieswear           Womens Everyday Basics                   score=1.55
#  397068015  Skinny L.W Bargain (1)    Trousers             Menswear             Denim Men                                score=1.54
#  584483002  Alien                     Blouse               Ladieswear           Womens Everyday Collection               score=1.52
#  648255001  Gelato                    Skirt                Ladieswear           Womens Everyday Collection               score=1.49
#
# ************************************************************
#   Recomendations for user_id = 39.0
# ************************************************************
#
#      Already bought:
#  679526002  BUDDY ls 2p aop           T-shirt              Baby/Children        Girls Underwear & Basics
#  552370002  SKINNY PRICE              Trousers             Baby/Children        Young Girl
#  627572008  Kompis L/S fancy          Sweater              Baby/Children        Girls Underwear & Basics
#  502186012  Tuck cropped sweater      Sweater              Ladieswear           Womens Casual
#  660367001  DESIREE half zip          Hoodie               Sport                Ladies H&M Sport
#  626052009  BIM shirt                 Blouse               Baby/Children        Young Girl
#  564418001  Lima denim shirt          Shirt                Divided              Ladies Denim
#  555366001  DUNGAREE L/L BASIC SLIM   Dungarees            Baby/Children        Young Girl
#  634019001  DUNGAREE LL SLIM ANNA     Dungarees            Baby/Children        Young Girl
#  625819005  J shirt                   Shirt                Ladieswear           Womens Casual
#  562245018  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection
#  610776001  Tilly (1)                 T-shirt              Ladieswear           Womens Everyday Basics
#  504154022  Lady Di                   Sweater              Ladieswear           Womens Everyday Collection
#  626263008  GILDA LEGGINGS            Leggings/Tights      Baby/Children        Young Girl
#  626263008  GILDA LEGGINGS            Leggings/Tights      Baby/Children        Young Girl
#  558981004  Gilda                     Leggings/Tights      Baby/Children        Young Girl
#  565379023  Moa tank                  Vest top             Ladieswear           Womens Everyday Basics
#  626263002  GILDA LEGGINGS            Leggings/Tights      Baby/Children        Young Girl
#  634727002  Fraiser Padded Jkt        Jacket               Ladieswear           Womens Jackets
#  562245057  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection
#
#      Recommended:
#  253448003  OP Push Melbourne^        Bra                  Ladieswear           Womens Lingerie                          score=1.22
#  253448001  OP Push Melbourne^        Bra                  Ladieswear           Womens Lingerie                          score=1.07
#  569526002  CHIPMUNK loose tee (1)    T-shirt              Sport                Ladies H&M Sport                         score=0.928
#  522561002  Seine coat                Coat                 Ladieswear           Womens Jackets                           score=0.897
#  630141001  HAVANA TIGHTS             Leggings/Tights      Sport                Ladies H&M Sport                         score=0.833
#  583534002  Bradley                   Trousers             Ladieswear           Womens Everyday Basics                   score=0.77
#  634411001  LOUISE basic tee          T-shirt              Sport                Ladies H&M Sport                         score=0.711
#  537612026  JOSSAN Boxy Hood (1)      Hoodie               Baby/Children        Girls Underwear & Basics                 score=0.622
#  487827007  Super soft                Trousers             Divided              Ladies Denim                             score=0.608
#  560270007  NORWAY fleece jacket (1)  Hoodie               Sport                Ladies H&M Sport                         score=0.601
#  156231001  Box 4p Tights             Underwear Tights     Ladieswear           Womens Nightwear, Socks & Tigh           score=0.599
#  630145001  FLORIDA TIGHTS            Leggings/Tights      Sport                Ladies H&M Sport                         score=0.596
#
# ************************************************************
#   Recomendations for user_id = 44.0
# ************************************************************
#
#      Already bought:
#  179208001  Control Top 100 den 1p Tights Leggings/Tights      Ladieswear           Womens Nightwear, Socks & Tigh
#  573937001  ED Madison Skinny HW      Trousers             Ladieswear           H&M+
#  620081008  Tulip jumper              Sweater              Ladieswear           Womens Everyday Collection
#  672054004  MARS SET                  Sweater              Baby/Children        Kids Boy
#  266875001  Sportsneaker 3p socks     Socks                Ladieswear           Womens Nightwear, Socks & Tigh
#  448515018  Kendall RW Denim TRS      Trousers             Divided              Divided Collection
#  684686001  Skinny Ankle R.W Chic Trash Trousers             Divided              Ladies Denim
#  554772015  Bob V-neck                T-shirt              Ladieswear           Womens Everyday Basics
#  452618001  Clean Edge 60 den 1p Leggings Underwear Tights     Ladieswear           Womens Nightwear, Socks & Tigh
#
#      Recommended:
#  189616006  Heavy jsy long leg        Leggings/Tights      Divided              Divided Basics                           score=1.5
#  355072001  Anita Tank (1)            Vest top             Divided              Divided Basics                           score=1.41
#  657497001  Bellini price CF          Sweater              Divided              Divided Collection                       score=1.39
#  683662005  Doris L/S                 Top                  Divided              Divided Basics                           score=1.35
#  399223001  Curvy Jeggings HW Ankle   Trousers             Divided              Ladies Denim                             score=1.3
#  640124003  Leeds Jumper              Sweater              Divided              Divided Collection                       score=1.25
#  633130002  Zebra sweater TOP PRODUCT Sweater              Divided              Divided Collection                       score=1.23
#  589222001  Skinny H.W Air            Trousers             Divided              Ladies Denim                             score=1.21
#  189634001  Long Leg Leggings         Leggings/Tights      Divided              Divided Basics                           score=1.2
#  657497006  Bellini price CF          Sweater              Divided              Divided Collection                       score=1.19
#  189616007  Heavy jsy long leg        Leggings/Tights      Divided              Divided Basics                           score=1.18
#  633130016  Zebra sweater TOP PRODUCT Sweater              Divided              Divided Collection                       score=1.15
#
# ************************************************************
#   Recomendations for user_id = 95.0
# ************************************************************
#
#      Already bought:
#  562211001  Ariel hip belt            Belt                 Ladieswear           Womens Big accessories
#  660830006  Fine knit heaven          Sweater              Ladieswear           Womens Everyday Collection
#  663185002  Speed Gwen Bangle         Bracelet             Ladieswear           Womens Small accessories
#  666061003  Harry SP                  Bra                  Ladieswear           Womens Lingerie
#  591334020  Flock                     Sweater              Ladieswear           Womens Everyday Basics
#  580000002  50 cent thong (O)         Underwear bottom     Ladieswear           Womens Lingerie
#  657291001  Dawn magnolia thong       Underwear bottom     Ladieswear           Womens Lingerie
#  660519002  Haven back detail         Bra                  Ladieswear           Womens Lingerie
#  569355007  Alma Sneaker              Sneakers             Ladieswear           Womens Shoes
#  636455012  Jennifer (1)              Blazer               Ladieswear           Womens Everyday Collection
#  668640001  Fringe top                Sweater              Ladieswear           Womens Casual
#  668640001  Fringe top                Sweater              Ladieswear           Womens Casual
#  687940004  J STAN TEE EQ             T-shirt              Ladieswear           Womens Everyday Collection
#  572124003  Vintage Ankle Skinny H.W  Trousers             Divided              Ladies Denim
#
#      Recommended:
#  666080002  Atlanta Push Lace Valencia Bra                  Ladieswear           Womens Lingerie                          score=2.11
#  691543001  Sienna                    Blouse               Ladieswear           Womens Tailoring                         score=1.86
#  666006006  Milla pile                Jacket               Ladieswear           Womens Jackets                           score=1.69
#  529008026  Hazelnut Push Melbourne   Bra                  Ladieswear           Womens Lingerie                          score=1.65
#  487722007  Charlotte Body Push Melbourne Underwear body       Ladieswear           Womens Lingerie                          score=1.51
#  657291004  Dawn magnolia thong       Underwear bottom     Ladieswear           Womens Lingerie                          score=1.48
#  657287003  Dawn padded Tshirt        Bra                  Ladieswear           Womens Lingerie                          score=1.47
#  589222005  Skinny H.W Air            Trousers             Divided              Ladies Denim                             score=1.41
#  519583015  Skinny R.W Chic           Trousers             Divided              Ladies Denim                             score=1.37
#  507909001  Rebecca or Delphine shirt Shirt                Ladieswear           Womens Tailoring                         score=1.35
#  649059002  Atlanta Hipster Ch. Poppy Mid Underwear bottom     Ladieswear           Womens Lingerie                          score=1.3
#  677967009  Nutella Push Melbourne    Bra                  Ladieswear           Womens Lingerie                          score=1.3
#
# ************************************************************
#   Recomendations for user_id = 161.0
# ************************************************************
#
#      Already bought:
#  541308009  BO fancy OH BB            Hoodie               Baby/Children        Boys Underwear & Basics
#  566592013  Princeton shirt           Shirt                Baby/Children        Young Boy
#  541720001  Brando Hood               Hoodie               Baby/Children        Young Boy
#  610822017  Miles s/s t-shirt         T-shirt              Baby/Children        Young Boy
#  594879003  Steve collarless shirt    Shirt                Baby/Children        Young Boy
#  566534011  Joe chinos                Trousers             Baby/Children        Young Boy
#  564934006  Ben ss polo               T-shirt              Baby/Children        Young Boy
#  636863001  BB Alban Anorak           Jacket               Baby/Children        Kids Outerwear
#  566556004  Malcolm 5-pkt             Trousers             Baby/Children        Young Boy
#  403479001  TP BILLY Basic 2-p S/S r n BB T-shirt              Baby/Children        Boys Underwear & Basics
#  403479001  TP BILLY Basic 2-p S/S r n BB T-shirt              Baby/Children        Boys Underwear & Basics
#  562245050  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection
#  508543005  BEN POLO TP               Polo shirt           Baby/Children        Kids Boy
#  640530002  Liverpool collarless shirt Shirt                Baby/Children        Kids Boy
#  537839003  Pedro Push Melbourne      Bra                  Ladieswear           Womens Lingerie
#  627389005  Venice                    Sweater              Ladieswear           Womens Everyday Basics
#  485546006  Justin 2-p tank SB        Vest top             Baby/Children        Boys Underwear & Basics
#  555837002  Oscar jogger              Trousers             Baby/Children        Kids Boy
#  567745004  SB Bobby jkt              Jacket               Baby/Children        Kids Outerwear
#  416511002  Julia Denim Petite Trs    Trousers             Divided              Divided Collection
#  571982017  Billy twill               Trousers             Baby/Children        Kids Boy
#  568498001  Paddington Crewneck       Sweater              Baby/Children        Kids Boy
#  544739009  ALEX 2-p s/s SB           T-shirt              Baby/Children        Boys Underwear & Basics
#  594581034  HAPPY PRICE SS TEE        T-shirt              Baby/Children        Kids Boy
#  568174022  Princeton shirt           Shirt                Baby/Children        Kids Boy
#  613569002  Pinus Jacket              Jacket               Ladieswear           Womens Jackets
#  639478001  Maybe you need a cardigan Cardigan             Ladieswear           Womens Everyday Collection
#  601551001  Benji 3 pack              T-shirt              Baby/Children        Kids Boy
#
#      Recommended:
#  729931001  ED Coated leggings.       Trousers             Ladieswear           H&M+                                     score=1.55
#  562245018  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection               score=1.39
#  567594001  Cosy tunic                Dress                Ladieswear           H&M+                                     score=1.3
#  562245042  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection               score=1.29
#  573085001  Madison skinny HW         Trousers             Ladieswear           Womens Everyday Collection               score=1.19
#  569996001  R-NECK SS BASIC FIT       T-shirt              Menswear             Men Underwear                            score=1.16
#  617322005  Glans tunic               Blouse               Ladieswear           H&M+                                     score=1.16
#  581162008  Beth sandal               Sandals              Ladieswear           Womens Shoes                             score=1.13
#  572400001  Taya Hood                 Hoodie               Divided              Divided Basics                           score=1.13
#  562245001  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection               score=1.11
#  494691001  Skinny HW Ankle Phoenix 14.99 Trousers             Divided              Ladies Denim                             score=1.1
#  562252010  Space jegging             Trousers             Ladieswear           Womens Everyday Collection               score=0.975
#
# ************************************************************
#   Recomendations for user_id = 334.0
# ************************************************************
#
#      Already bought:
#  573085020  Madison skinny HW (1)     Trousers             Ladieswear           Womens Everyday Collection
#  573085020  Madison skinny HW (1)     Trousers             Ladieswear           Womens Everyday Collection
#  637549004  Bama                      Sweater              Ladieswear           Womens Everyday Collection
#  537116001  Tara turtleneck top       Sweater              Ladieswear           Womens Tailoring
#
#      Recommended:
#  685687001  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=2.34
#  685687002  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=2.26
#  685687003  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=2.25
#  685687004  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=2.17
#  524825013  Latte slacks (1)          Trousers             Ladieswear           Womens Everyday Collection               score=2.0
#  662868003  Daisy                     Sweater              Ladieswear           Womens Everyday Collection               score=1.96
#  524825012  Latte slacks (1)          Trousers             Ladieswear           Womens Everyday Collection               score=1.95
#  671505002  EDC ROMAN BLOUSE          Blouse               Ladieswear           Womens Everyday Collection               score=1.94
#  661162003  Teddy                     Sweater              Ladieswear           Womens Tailoring                         score=1.92
#  683662005  Doris L/S                 Top                  Divided              Divided Basics                           score=1.89
#  667491011  Bloom                     Shirt                Ladieswear           Womens Everyday Collection               score=1.85
#  671505004  EDC ROMAN BLOUSE          Blouse               Ladieswear           Womens Everyday Collection               score=1.81
#
# ************************************************************
#   Recomendations for user_id = 391.0
# ************************************************************
#
#      Already bought:
#  672224001  Rubena                    Boots                Ladieswear           Womens Shoes
#  626813009  Syrup ISW 19              Blouse               Ladieswear           Womens Everyday Collection
#  626813009  Syrup ISW 19              Blouse               Ladieswear           Womens Everyday Collection
#  636455012  Jennifer (1)              Blazer               Ladieswear           Womens Everyday Collection
#  612182014  Pluto RW slacks           Trousers             Ladieswear           Womens Everyday Collection
#
#      Recommended:
#  573716012  Kanta slacks RW           Trousers             Ladieswear           Womens Everyday Collection               score=2.56
#  524825012  Latte slacks (1)          Trousers             Ladieswear           Womens Everyday Collection               score=2.1
#  688873001  Gyda!                     Blouse               Ladieswear           Womens Tailoring                         score=2.07
#  573716002  Kanta slacks              Trousers             Ladieswear           Womens Everyday Collection               score=2.04
#  612182001  Pluto RW slacks           Trousers             Ladieswear           Womens Everyday Collection               score=1.97
#  685687004  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.9
#  507909022  Rebecca                   Shirt                Ladieswear           Womens Tailoring                         score=1.85
#  568601006  Mariette Blazer           Blazer               Ladieswear           Womens Tailoring                         score=1.81
#  524825011  Latte slacks (1)          Trousers             Ladieswear           Womens Everyday Collection               score=1.75
#  524825014  Latte slacks (1)          Trousers             Ladieswear           Womens Everyday Collection               score=1.74
#  568808001  Vermont Summer Slacks     Trousers             Ladieswear           Womens Tailoring                         score=1.73
#  685687001  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.73
#
# ************************************************************
#   Recomendations for user_id = 562.0
# ************************************************************
#
#      Already bought:
#  623840002  H-string basic 10pk       Hair string          Baby/Children        Kids Accessories, Swimwear & D
#  662888001  Miranda                   Sweater              Ladieswear           Womens Everyday Collection
#  619739008  Rally 2-p.                Underwear Tights     Baby/Children        Girls Underwear & Basics
#  562252035  Space 5 pkt tregging      Trousers             Ladieswear           Womens Everyday Collection
#
#      Recommended:
#  665481004  Swift Dress               Dress                Ladieswear           Womens Tailoring                         score=1.95
#  685687001  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.85
#  524825019  Latte slacks (1)          Trousers             Ladieswear           Womens Everyday Collection               score=1.79
#  568808001  Vermont Summer Slacks     Trousers             Ladieswear           Womens Tailoring                         score=1.75
#  495685001  Rollerneck Blenheim TVP   Sweater              Menswear             Men Suits & Tailoring                    score=1.71
#  657287001  Dawn padded Tshirt        Bra                  Ladieswear           Womens Lingerie                          score=1.7
#  573716040  Kanta slacks              Trousers             Ladieswear           Womens Everyday Collection               score=1.69
#  599502001  Kia Paperbag (1)          Trousers             Ladieswear           Womens Tailoring                         score=1.66
#  685687004  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.64
#  688873014  Gyda!                     Blouse               Ladieswear           Womens Tailoring                         score=1.51
#  652742003  Saga                      Dress                Ladieswear           Womens Tailoring                         score=1.51
#  516903005  Sally Structure TVP       Sweater              Divided              Divided Collection                       score=1.5
#
# ************************************************************
#   Recomendations for user_id = 597.0
# ************************************************************
#
#      Already bought:
#  621523007  Fav Polo solid            Polo shirt           Menswear             Contemporary Casual
#  479227018  Stacy                     T-shirt              Ladieswear           Womens Everyday Basics
#  560270003  NORWAY fleece jacket      Hoodie               Sport                Ladies H&M Sport
#  396135052  Glamping                  Shorts               Ladieswear           Womens Everyday Basics
#  488697013  Nohar Sneaker             Sneakers             Menswear             Men Shoes
#  456163022  Woody (1)                 Hoodie               Ladieswear           Womens Everyday Basics
#
#      Recommended:
#  605106001  Rose thong                Underwear bottom     Divided              Divided Basics                           score=1.8
#  237347036  Theron                    Hoodie               Ladieswear           Womens Everyday Basics                   score=1.58
#  372860001  7p Basic Shaftless        Socks                Ladieswear           Womens Nightwear, Socks & Tigh           score=1.34
#  631837003  Eclipse price hood        Sweater              Divided              Divided Collection                       score=1.32
#  636926001  Mariah                    Top                  Ladieswear           Womens Everyday Collection               score=1.24
#  575495003  Monet wide trouser        Trousers             Ladieswear           Womens Everyday Collection               score=1.22
#  685687003  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.22
#  538142004  Skinny R.W Ankle Chic     Trousers             Divided              Ladies Denim                             score=1.19
#  685687004  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.17
#  355072003  Anita Tank (1)            Vest top             Divided              Divided Basics                           score=1.15
#  625939014  Cat Tee                   T-shirt              Divided              Divided Basics                           score=1.14
#  634015010  FOG tanktop               Vest top             Sport                Ladies H&M Sport                         score=1.13
#
# ************************************************************
#   Recomendations for user_id = 604.0
# ************************************************************
#
#      Already bought:
#  637255001  Gloss                     Dress                Ladieswear           Womens Everyday Basics
#  637255001  Gloss                     Dress                Ladieswear           Womens Everyday Basics
#  692454002  EDC LAURA LACE TOP        Top                  Ladieswear           Womens Everyday Collection
#  692454002  EDC LAURA LACE TOP        Top                  Ladieswear           Womens Everyday Collection
#  684588001  Yen.                      Blouse               Ladieswear           Womens Everyday Collection
#
#      Recommended:
#  399223001  Curvy Jeggings HW Ankle   Trousers             Divided              Ladies Denim                             score=1.97
#  685687004  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.92
#  685687003  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.91
#  685687001  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.76
#  685687002  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.7
#  562245001  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection               score=1.63
#  589222001  Skinny H.W Air            Trousers             Divided              Ladies Denim                             score=1.52
#  399201020  Shaping Skinny H.W        Trousers             Divided              Ladies Denim                             score=1.49
#  573085001  Madison skinny HW         Trousers             Ladieswear           Womens Everyday Collection               score=1.47
#  399201005  Shaping Skinny H.W        Trousers             Divided              Ladies Denim                             score=1.46
#  573085020  Madison skinny HW (1)     Trousers             Ladieswear           Womens Everyday Collection               score=1.42
#  662888003  Miranda                   Sweater              Ladieswear           Womens Everyday Collection               score=1.37
#
# ************************************************************
#   Recomendations for user_id = 627.0
# ************************************************************
#
#      Already bought:
#  634009004  CERISE top                Vest top             Sport                Ladies H&M Sport
#  586333001  Bonnie blouse             Blouse               Ladieswear           Womens Casual
#  586333001  Bonnie blouse             Blouse               Ladieswear           Womens Casual
#  500399001  Roni Ruffle Blouse        Blouse               Divided              Divided Collection
#
#      Recommended:
#  524825013  Latte slacks (1)          Trousers             Ladieswear           Womens Everyday Collection               score=2.1
#  660712012  Kaj tapered               Trousers             Ladieswear           Womens Everyday Collection               score=1.79
#  685687001  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.73
#  581777008  Vintage H.W Ankle         Trousers             Ladieswear           Ladies Denim                             score=1.69
#  524825012  Latte slacks (1)          Trousers             Ladieswear           Womens Everyday Collection               score=1.68
#  667491011  Bloom                     Shirt                Ladieswear           Womens Everyday Collection               score=1.57
#  685687003  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.5
#  667378002  Tulip                     Trousers             Ladieswear           Womens Everyday Basics                   score=1.49
#  667379002  Gandi                     Sweater              Ladieswear           Womens Everyday Basics                   score=1.45
#  507909001  Rebecca or Delphine shirt Shirt                Ladieswear           Womens Tailoring                         score=1.42
#  639976002  Gainsbourgh               Jacket               Ladieswear           Womens Jackets                           score=1.41
#  636455009  Jennifer (1)              Blazer               Ladieswear           Womens Everyday Collection               score=1.39
#
# ************************************************************
#   Recomendations for user_id = 648.0
# ************************************************************
#
#      Already bought:
#  633130013  Zebra sweater TOP PRODUCT Sweater              Divided              Divided Collection
#  552471001  KELLY S.8                 Shirt                Divided              Divided Collection
#  552471001  KELLY S.8                 Shirt                Divided              Divided Collection
#  564358010  PAUL  R-NECK              Sweater              Menswear             Contemporary Smart
#  633130007  Zebra sweater TOP PRODUCT Sweater              Divided              Divided Collection
#
#      Recommended:
#  573716039  Kanta slacks              Trousers             Ladieswear           Womens Everyday Collection               score=1.29
#  565379001  Moa tank                  Vest top             Ladieswear           Womens Everyday Basics                   score=1.25
#  599502009  Kia Paperbag              Trousers             Ladieswear           Womens Tailoring                         score=1.19
#  565379002  Moa tank                  Vest top             Ladieswear           Womens Everyday Basics                   score=1.11
#  539723005  Jade Denim TRS            Trousers             Divided              Divided Collection                       score=1.03
#  679986005  COZY FREDDY JOGGER RW     Trousers             Ladieswear           Womens Casual                            score=0.951
#  672890003  Frida Printed Sweater     Sweater              Divided              Divided Collection                       score=0.945
#  446224014  Maja Cardigan             Cardigan             Divided              Divided Collection                       score=0.938
#  189634001  Long Leg Leggings         Leggings/Tights      Divided              Divided Basics                           score=0.928
#  620081006  Tulip jumper              Sweater              Ladieswear           Womens Everyday Collection               score=0.912
#  677848001  LS PJ DEAL                Pyjama jumpsuit/playsuit Baby/Children        Baby Essentials & Complements            score=0.906
#  573716012  Kanta slacks RW           Trousers             Ladieswear           Womens Everyday Collection               score=0.897
#
# ************************************************************
#   Recomendations for user_id = 725.0
# ************************************************************
#
#      Already bought:
#  547747001  Mimi star coating         Trousers             Ladieswear           Womens Everyday Collection
#  547747001  Mimi star coating         Trousers             Ladieswear           Womens Everyday Collection
#  694589005  Lexy cropped hoodie       Hoodie               Divided              Divided Basics
#  656015001  Roxy Ringer Tee           T-shirt              Divided              Divided Complements Other
#  578876005  HAMILTON P5               T-shirt              Ladieswear           Womens Casual
#  562252010  Space jegging             Trousers             Ladieswear           Womens Everyday Collection
#
#      Recommended:
#  399136011  Shaping Skinny R.W        Trousers             Divided              Ladies Denim                             score=1.79
#  539723005  Jade Denim TRS            Trousers             Divided              Divided Collection                       score=1.73
# ...
#  656031001  Eden Hipster Ch. Poppy Mid Underwear bottom     Ladieswear           Womens Lingerie
#  683662002  Doris L/S                 Top                  Divided              Divided Basics
#  677967003  Nutella Push Melbourne    Bra                  Ladieswear           Womens Lingerie
#  677967003  Nutella Push Melbourne    Bra                  Ladieswear           Womens Lingerie
#  683662006  Doris L/S                 Top                  Divided              Divided Basics
#
#      Recommended:
#  685687001  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=2.35
#  637673005  Techno                    Sweater              Ladieswear           Womens Everyday Collection               score=2.24
#  685687004  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=2.18
#  611415005  Charlotte Brazilian Aza.Low 2p Underwear bottom     Ladieswear           Womens Lingerie                          score=2.15
#  637549005  Bama                      Sweater              Ladieswear           Womens Everyday Collection               score=2.13
#  685687003  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=2.07
#  562245034  Luna skinny 5 pkt         Trousers             Ladieswear           Womens Everyday Collection               score=2.04
#  685687002  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=2.02
#  662857005  Cindererlla               Sweater              Ladieswear           Womens Everyday Collection               score=2.0
#  662868003  Daisy                     Sweater              Ladieswear           Womens Everyday Collection               score=1.98
#  660599001  Baraboom (1)              Cardigan             Ladieswear           Womens Everyday Collection               score=1.9
#  539723001  Jade Denim TRS            Trousers             Divided              Divided Collection                       score=1.85
#
# ************************************************************
#   Recomendations for user_id = 22051.0
# ************************************************************
#
#      Already bought:
#  662722002  Fur friends fancy         Soft Toys            Baby/Children        Kids Accessories, Swimwear & D
#  673024005  Betty hood                Hoodie               Baby/Children        Kids Girl
#  673024003  Betty hood                Hoodie               Baby/Children        Kids Girl
#  673024003  Betty hood                Hoodie               Baby/Children        Kids Girl
#  673942003  Lilou dress               Dress                Baby/Children        Kids Girl
#  673942003  Lilou dress               Dress                Baby/Children        Kids Girl
#  659320003  Klara Dress               Dress                Baby/Children        Kids Girl
#  659320003  Klara Dress               Dress                Baby/Children        Kids Girl
#  611144006  Badger Fancy              Sweater              Baby/Children        Kids Girl
#  611144006  Badger Fancy              Sweater              Baby/Children        Kids Girl
#  652978001  STELLA Premium Scarf      Scarf                Baby/Children        Kids Outerwear
#  618398003  Badger price              Sweater              Baby/Children        Kids Girl
#
#      Recommended:
#  562211001  Ariel hip belt            Belt                 Ladieswear           Womens Big accessories                   score=2.0
#  625321010  SPEEDY tee conscious      T-shirt              Sport                Ladies H&M Sport                         score=1.85
#  575347003  7pk basic R sneaker socks Socks                Menswear             Men Underwear                            score=1.76
#  620745003  OL BARNES Espadrille      Flat shoe            Ladieswear           Womens Shoes                             score=1.73
#  657287001  Dawn padded Tshirt        Bra                  Ladieswear           Womens Lingerie                          score=1.72
#  691543001  Sienna                    Blouse               Ladieswear           Womens Tailoring                         score=1.7
#  655784003  Noa slim PRICE            Trousers             Ladieswear           Womens Tailoring                         score=1.63
#  703193001  EDC GABRIELLE DRESSS      Dress                Ladieswear           Womens Everyday Collection               score=1.6
#  556527002  SKINNY SS Trash 89        Trousers             Baby/Children        Young Boy                                score=1.58
#  589222005  Skinny H.W Air            Trousers             Divided              Ladies Denim                             score=1.53
#  589222001  Skinny H.W Air            Trousers             Divided              Ladies Denim                             score=1.5
#  567594001  Cosy tunic                Dress                Ladieswear           H&M+                                     score=1.49
#
# ************************************************************
#   Recomendations for user_id = 22067.0
# ************************************************************
#
#      Already bought:
#  620208031  NIKE legging              Leggings/Tights      Baby/Children        Girls Underwear & Basics
#  640168001  MELINA                    Cardigan             Baby/Children        Young Girl
#  641047003  Essie well dressed        Dress                Baby/Children        Young Girl
#  619739006  Rally 2-p.                Underwear Tights     Baby/Children        Girls Underwear & Basics
#
#      Recommended:
#  652730003  Katie Skirt               Skirt                Ladieswear           Womens Tailoring                         score=1.45
#  703193001  EDC GABRIELLE DRESSS      Dress                Ladieswear           Womens Everyday Collection               score=1.45
#  619506002  TEA sport socks (1)       Socks                Sport                Ladies H&M Sport                         score=1.39
#  620208002  NIKE legging              Leggings/Tights      Baby/Children        Girls Underwear & Basics                 score=1.3
#  688873020  Gyda!                     Blouse               Ladieswear           Womens Tailoring                         score=1.29
#  630116001  SUPREME TIGHTS            Leggings/Tights      Sport                Ladies H&M Sport                         score=1.27
#  652840001  Svenne SET                Garment Set          Baby/Children        Baby Boy                                 score=1.27
#  562245018  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection               score=1.22
#  317812001  LOLLY SKIRT (1)           Skirt                Baby/Children        Girls Underwear & Basics                 score=1.2
#  293433002  Basic 2PACK tights KG     Underwear Tights     Baby/Children        Girls Underwear & Basics                 score=1.16
#  653409003  Blunder coat              Coat                 Ladieswear           Womens Trend                             score=1.16
#  605290002  Karlie 2p                 T-shirt              Baby/Children        Young Girl                               score=1.16
#
# ************************************************************
#   Recomendations for user_id = 22086.0
# ************************************************************
#
#      Already bought:
#  533406024  Frank Tech Pant           Trousers             Sport                Men H&M Sport
#  595779002  Offy sweater              Sweater              Ladieswear           Womens Everyday Collection
#  641891001  Joffrey bomber            Jacket               Divided              Divided Collection
#  653716003  Hal shorts                Shorts               Sport                Men H&M Sport
#
#      Recommended:
#  671505002  EDC ROMAN BLOUSE          Blouse               Ladieswear           Womens Everyday Collection               score=1.47
#  562245058  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection               score=1.28
#  573937001  ED Madison Skinny HW      Trousers             Ladieswear           H&M+                                     score=1.27
#  657476008  London 9.99               T-shirt              Divided              Divided Collection                       score=1.25
#  578478003  Pep leggings              Trousers             Ladieswear           Womens Tailoring                         score=1.21
#  685687003  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.21
#  562245001  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection               score=1.19
#  399223001  Curvy Jeggings HW Ankle   Trousers             Divided              Ladies Denim                             score=1.13
#  573085020  Madison skinny HW (1)     Trousers             Ladieswear           Womens Everyday Collection               score=1.11
#  399201005  Shaping Skinny H.W        Trousers             Divided              Ladies Denim                             score=1.11
#  539723001  Jade Denim TRS            Trousers             Divided              Divided Collection                       score=1.1
#  685284001  Bowy skirt                Skirt                Ladieswear           Womens Everyday Collection               score=1.09
#
# ************************************************************
#   Recomendations for user_id = 22237.0
# ************************************************************
#
#      Already bought:
#  625630002  Karlshamn strap top       Blouse               Ladieswear           Womens Casual
#  458925002  Javier                    Top                  Ladieswear           Womens Everyday Collection
#  108775051  Strap top (1)             Vest top             Ladieswear           Womens Everyday Basics
#  615141002  Juanos                    Top                  Ladieswear           Womens Everyday Collection
#  608952004  Fire                      Sweater              Ladieswear           Womens Everyday Collection
#
#      Recommended:
#  589924004  Nord tee                  Top                  Ladieswear           Womens Everyday Collection               score=1.77
#  685687002  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.73
#  685687003  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.63
#  685687004  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.57
#  685687001  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.57
#  642699001  Nancy                     T-shirt              Ladieswear           Womens Casual                            score=1.52
#  494691001  Skinny HW Ankle Phoenix 14.99 Trousers             Divided              Ladies Denim                             score=1.52
#  189634001  Long Leg Leggings         Leggings/Tights      Divided              Divided Basics                           score=1.47
#  611062002  GDC Zoe                   Blouse               Ladieswear           Womens Everyday Collection               score=1.47
#  589924003  Nord tee                  Top                  Ladieswear           Womens Everyday Collection               score=1.37
#  589222001  Skinny H.W Air            Trousers             Divided              Ladies Denim                             score=1.36
#  562245001  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection               score=1.3
#
# ************************************************************
#   Recomendations for user_id = 22257.0
# ************************************************************
#
#      Already bought:
#  613246002  Luna destroy (1)          Trousers             Ladieswear           Womens Everyday Collection
#  613246006  Luna destroy (1)          Trousers             Ladieswear           Womens Everyday Collection
#  694589003  Lexy cropped hoodie       Hoodie               Divided              Divided Basics
#  572124006  Vintage Ankle Skinny H.W  Trousers             Divided              Ladies Denim
#  610671001  Perrie trash              Trousers             Divided              Divided Collection
#  651793001  Craven set                Sweater              Baby/Children        Young Girl
#  651793002  Craven set                Sweater              Baby/Children        Young Girl
#  558996002  JLO                       Leggings/Tights      Baby/Children        Young Girl
#  558981009  Gilda                     Leggings/Tights      Baby/Children        Young Girl
#  572942002  Charlie Denim Dungaree    Trousers             Divided              Divided Collection
#  563551005  Dixe sweater              Top                  Baby/Children        Young Girl
#  559069003  MY hood                   Hoodie               Baby/Children        Young Girl
#  558981019  Gilda                     Leggings/Tights      Baby/Children        Young Girl
#  620569001  Millie sweater            Sweater              Baby/Children        Young Girl
#  605378003  LAUREN PRICE SWETTIS      Sweater              Baby/Children        Young Girl
#
#      Recommended:
#  399201005  Shaping Skinny H.W        Trousers             Divided              Ladies Denim                             score=1.77
#  399223001  Curvy Jeggings HW Ankle   Trousers             Divided              Ladies Denim                             score=1.64
#  633130020  Zebra sweater TOP PRODUCT Sweater              Divided              Divided Collection                       score=1.53
#  399136061  Shaping Skinny R.W.       Trousers             Divided              Ladies Denim                             score=1.51
#  685687004  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.41
#  562245018  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection               score=1.34
#  457466002  Control Top 15 den 1p Tights Underwear Tights     Ladieswear           Womens Nightwear, Socks & Tigh           score=1.34
#  562245001  Luna skinny RW            Trousers             Ladieswear           Womens Everyday Collection               score=1.32
#  554450027  Julia RW Skinny Denim TRS Trousers             Divided              Divided Collection                       score=1.31
#  399201011  Shaping Skinny H.W        Trousers             Divided              Ladies Denim                             score=1.29
#  685687003  W YODA KNIT OL OFFER      Sweater              Ladieswear           Womens Everyday Collection               score=1.28
#  399136027  Shaping Skinny R.W.       Trousers             Divided              Ladies Denim                             score=1.28

# %%
import pickle

with open('lightfm_preds', 'wb') as fp:
    pickle.dump(lightfm_preds, fp)

# %% [markdown]
# # Visualisations

# %%
def sample_recommendation_with_image(model, transactions_df, articles_df, article_dict, num, user_ids):

    items = transactions_df.article_id_enc.unique()
    #print(items[:10])

    for user_id in user_ids:

        print("  Recomendations for user_id =", user_id)

        bought = transactions_df[transactions_df["customer_id_enc"] == user_id]["article_id"].values

        # make prediction 
        scores = model.predict(np.ones(len(items)) * user_id, items)
        
        # n-top score 
        num_of_cand = 50
        argsort_scores_idx = np.argsort(scores)[-num_of_cand:]
        argsort_scores_idx = np.flip(argsort_scores_idx)

        
        recomended = []
        k = 1
        for ind in argsort_scores_idx:
            ii = article_dict[items[ind]]
            
            # check if already bought
            if ii in bought:
                continue
            else: k+=1
                
            recomended.append(ii)

            if k > num: break
        #print()
    
    #print("Already bought")
    
    img_list_bought = []
    for id in bought:
        
        image_path = "../input/h-and-m-personalized-fashion-recommendations/images/0{}/0{}.jpg".format(str(id)[:2], id)

        try:
            img = Image.open(image_path)
        except FileNotFoundError:
            continue 
            
        img_list_bought.append(img)

    plt.figure(figsize=(10,5))
    for j in range(len(bought)):
        plt.subplot(1, len(bought), j+1)
        plt.axis('off')
        plt.imshow(img_list_bought[j])
        plt.title("Already bought", fontdict=None, loc='center')

    img_list_recomended = [] 
    for id in recomended:
        image_path = "../input/h-and-m-personalized-fashion-recommendations/images/0{}/0{}.jpg".format(str(id)[:2], id)
        #print(image_path)
        try:
            img = Image.open(image_path)
        except FileNotFoundError:
            continue 
            
        img_list_recomended.append(img)

    plt.figure(figsize=(10,20))
    for j in range(len(recomended)):
        plt.subplot(1, len(recomended), j+1)
        plt.axis('off')
        plt.imshow(img_list_recomended[j])  
        
        plt.title("Recomendations", fontdict=None, loc='center')    
    #return bought, recomended

#sample_recommendation_with_image(model, transactions_df_sample, articles_df.set_index("article_id"), article_dict, 5, [8])

# %% [markdown]
# # Metrics

# %%
ground_truth_list = []

# go through all customers from test list
for k, customer in enumerate(customer_test_df.customer_id):
    ground_truth_list.append(np.array(
        customer_test_df_hiden_transactions[customer_test_df_hiden_transactions.customer_id == customer].article_id))
    
print(len(ground_truth_list))
# Out:
# 500

# %%
def jaccard_similarity(list1, list2):
    intersection = len(list(set(list1).intersection(list2)))
    union = (len(set(list1)) + len(set(list2))) - intersection
    return float(intersection) / union

def jaccard(actual, predicted):
    return np.mean([jaccard_similarity(a,b) for a,b in zip(actual, predicted)])

def dice_similarity(list1, list2):
    intersection = 2 * len(list(set(list1).intersection(list2)))
    union = (len(set(list1)) + len(set(list2))) 
    return float(intersection) / union

def dice(actual, predicted):
    return np.mean([dice_similarity(a,b) for a,b in zip(actual, predicted)])

def intersept(list1, list2):
    return np.sum([len(list(set(a).intersection(b))) for a,b in zip(list1, list2)])

def apk(actual, predicted, k=10):
    """
    Computes the average precision at k.
    This function computes the average prescision at k between two lists of
    items.
    Parameters
    ----------
    actual : list
             A list of elements that are to be predicted (order doesn't matter)
    predicted : list
                A list of predicted elements (order does matter)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The average precision at k over the input lists
    """
    if len(predicted)>k:
        predicted = predicted[:k]

    score = 0.0
    num_hits = 0.0

    for i,p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i+1.0)

    #if not actual:
    #    return 0.0

    return score / min(len(actual), k)


def mapk(actual, predicted, k=10):
    """
    Computes the mean average precision at k.
    This function computes the mean average prescision at k between two lists
    of lists of items.
    Parameters
    ----------
    actual : list
             A list of lists of elements that are to be predicted 
             (order doesn't matter in the lists)
    predicted : list
                A list of lists of predicted elements
                (order matters in the lists)
    k : int, optional
        The maximum number of predicted elements
    Returns
    -------
    score : double
            The mean average precision at k over the input lists
    """
    return np.mean([apk(a,p,k) for a,p in zip(actual, predicted)])



def metrics(ground_truth, mp_preds):
    mp_interception = intersept(ground_truth_list, mp_preds)
    mp_jaccard_similarity = jaccard(ground_truth_list, mp_preds)
    mp_dice = dice(ground_truth_list, mp_preds)    
    mp_maok12 = mapk(ground_truth_list, mp_preds, 12)

    print("Interceptions: {} from {} ({:.4}%)".format(mp_interception, len(ground_truth) * 12, mp_interception*100/(len(ground_truth) * 12)) )
    print("Jaccard: {:.4}".format(mp_jaccard_similarity))
    print("Dice: {:.4}".format(mp_dice))
    print("Mean Average Precision @ 12: {:.4}".format(mp_maok12))
    
    return [mp_interception, mp_interception*100/(len(ground_truth) * 12), mp_jaccard_similarity, mp_dice, mp_maok12]

# %%
lightfm_preds[0]
# Out:
# [685687001,
#  685687004,
#  687424003,
#  693584002,
#  687424002,
#  662857005,
#  685687003,
#  662857004,
#  637549003,
#  660599003,
#  524825013,
#  665975002]

# %%
nlp12_metrics = metrics(ground_truth_list, lightfm_preds)
# Out:
# Interceptions: 177 from 6000 (2.95%)
# Jaccard: 0.01761
# Dice: 0.0325
# Mean Average Precision @ 12: 0.01191
